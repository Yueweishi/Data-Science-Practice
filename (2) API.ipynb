# %% [markdown]
# **Main Required Packages:**
#
# pandas, numpy, urllib (version stated in the next cell)

# %%
#restart kernel after executing this cell
pip install urllib3==1.26.6
# Out:
#   File "<ipython-input-53-bd3f62ec4a9b>", line 2
#     pip install urllib3==1.26.6
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # LAB 2. Part 1. Data Cleaning

# %% [markdown]
# The input data can be messy with all sorts of issues like
# * missing or incorrect values (e.g. entries containing nothing, zero, nan or wrong quantity);
# * misformatted records and entries (e.g. entries as strings instead of numeric or date-time or wrong number of entries per row);
# * duplicate records and other.
#
# In short a rule of thumb is that nothing can be taken for granted and need to be verified with format, value and sanity checks. Some issue just won't let you upload the data.
# With others Python could let you through but as we'll see in the case in the second notebook, if ingored, those issues can be substaintial enough to completely derail the analysis.
#
# So data cleaning is an important first step in any data analyics project. Consider an example of some real-estate data.

# %%
import pandas as pd
import numpy as np
import os
import urllib

# %%
#read the data and visualize as text to see what's inside

# %%
if not os.path.exists('Data'):
    # !mkdir Data
url = 'https://raw.githubusercontent.com/CUSP2020PUI/Data/master/RE_example11.csv'
urllib.request.urlretrieve(url,'Data/RE_example11.csv')
fname = 'Data/RE_example11.csv'
f = open(fname, 'r')
print(f.read())
f.close()
# Out:
# SALE DATE,ADDRESS,ZIP CODE,LAND SQUARE FEET,GROSS SQUARE FEET,YEAR BUILT,SALE PRICE
# 3/31/15, 8647 15TH AVENUE,11228,1547,1428,1930,758000
# 3/31/15, 8647 15TH AVENUE,11228,1547,1428,1930,758000
# 3/31/15, 8647 15TH AVENUE,11228,1547,1428,1930,758000
#
# 6/15/15, 55 BAY 10TH   STREET,11228,1933,1660,0,778000
#
# 9/16/15, 8620 19TH   AVENUE  ,11214,2417,2106,1930,0
#
# 5/29/15, 1906 86TH   STREET  ,11214,1900,2090,1931,1,365000
#
# 12/17/15, 50 BAY 23RD STREET  ,11214,2417,1672,1930,750000
#
# May,6,2015, 1964 86TH   STREET  ,11214,1725,2112,1925,1,470000
#
# 4/30/15, 1970 86TH   STREET  ,11214,1725,2112,1931,1,790000
#
# 7/24/15, 1638 BENSON AVENUE  ,11214,3625,1825,1925,820,000
#
# 6/25/15, 1653 BATH AVENUE,11214,1260,1440,1930,0
#
# 6/25/15, 1651 BATH AVENUE,11214,1260,1440,1930,0
#
# 10/17/15, 1731 BATH AVENUE,11214,1112,1520,1920,0
#
# 5/12/15, 121 BAY 17TH   STREET,11214,1619,912,1910,0
#
# 11/2/15, 244 BAY 8TH STREET  ,11228,5720,5152,1930,0
#
# 12/18/15, 239 BAY8TH STREET   ,11228,5810,1575,1950,1,850000
#
# 12/7/15, 8804 17TH AVENUE,,3,394,2288,1920,1,192000
#
# 8/24/15, 1942 BATH AVENUE,11214,2013,1980,1910,895000
#
# 9/14/15, 2018 BATH AVENUE,11214,1198,1596,1925,745000
#
# 4/30/15, 173 BAY 26TH STREET ,11214,1837,2337,1901,0
#
# 1/8/15, 265 BAY 8TH STREET  ,11228,3872,2688,2001,1,450000
#
# 10/8/15, 310 BAY 10TH STREET ,11228,3867,1399,1935,855000
#
# 1/16/15, 8846 16TH AVE   ,11214,1937,1240,1950,720000
#
# 11/2/15, 8870 16TH AVENUE,11214,1760,992,1950,620000
#
# 10/21/15, 1592 INDEPENDENCE AVENUE,11228,1844,992,1950,750000
#
# 2/25/15, 319 BAY 14TH STREET ,11214,1511,928,1950,0
#
# 11-20-15, 277 BAY 14 STREET   ,11214,1795,1204,1930,762000
#
# 6/5/15, 284 BAY 14TH   STREET,11214,1795,1152,1930,0
#
# Apr 24 2015, 308 BAY 14TH STREET ,11214,1511,992,1950,650000
#
# 7/20/15, 279 BAY 13TH   STREET,11214,1649,928,1940,0
#
# 11/18/15, 1127 SHORE PARKWAY  ,11214,1775,1188,1940,0
#
# 8/11/15, 8836 BAY 16TH STREET,11214,1865,2982,1960,860000
#
# 12/29/15, 8894 18TH AVENUE,11214,1361,992,1950,0
#
# 6/23/15, 287 BAY 20TH    ,11214,1551,1320,1940,675000
#
# 3/4/15, 241 BAY 23RD STREET ,11214,1783,1120,1945,10000
#
# 5/26/15, 8661 14TH AVENUE,11228,2,320,2160,1930,980000
#
# 10/22/15, 70 BAY 7TH STREET   ,11228,2320,2160,1930,750000
#
# 11/5/15, 37 BAY 7 STREET ,11228,2320,2160,1930,970000
#
# 4/21/15, 35 BAY 7TH ST   , ,2,320,2160,1930,855000
#
# 4/21/15, 35 BAY 7TH   STREET ,11228,2320,2160,1930,855000
# 10/21/15, 1592 INDEPENDENCE AVENUE,11228,1844,992,1950,750000
#
# 6/17/15, 1454 86TH STREET,11228,1600,3034,1931,0
#
# 11/17/15, 44 BAY 8TH   STREET ,11228,2320,2160,1930,nan
#
# 2/26/15, 44 BAY 8TH   STREET ,11228,2320,2160,1930,nan
#
# 12/28/15, 13 BAY 8TH ST   ,11228,2320,3160,1930,10
#
# 1/13/15, 1513 BENSON AVENUE  ,11228,2142,1920,1945,930000
#
# 2/17/15, 8625 15TH AVENUE,11228,2,312,2160,1930,950000
#
# 2/23/15, 37 BAY 10TH   STREET,11228,2103,1622,1930,0
# 10/21/15, 1592 INDEPENDENCE AVENUE,11228,1844,992,1950,750000
#
# 5/12/15, 31 BAY 10TH STREET  ,11228,2103,1622,1930,840,000
#
# 3/26/15, 13 BAY 10TH STREET  ,11228,2135,1622,1930,0
#
# 1/31/15, 8654 16TH AVENUE,11214,2492,2120,1935,0
#
# 12/28/15, 8653 16TH AVENUE,11214,none,1492,1930,769000

# %%
import requests
f = requests.get(url)
print(f.text)
# Out:
# SALE DATE,ADDRESS,ZIP CODE,LAND SQUARE FEET,GROSS SQUARE FEET,YEAR BUILT,SALE PRICE
# 3/31/15, 8647 15TH AVENUE,11228,1547,1428,1930,758000
# 3/31/15, 8647 15TH AVENUE,11228,1547,1428,1930,758000
# 3/31/15, 8647 15TH AVENUE,11228,1547,1428,1930,758000
# 6/15/15, 55 BAY 10TH   STREET,11228,1933,1660,0,778000
# 9/16/15, 8620 19TH   AVENUE  ,11214,2417,2106,1930,0
# 5/29/15, 1906 86TH   STREET  ,11214,1900,2090,1931,1,365000
# 12/17/15, 50 BAY 23RD STREET  ,11214,2417,1672,1930,750000
# May,6,2015, 1964 86TH   STREET  ,11214,1725,2112,1925,1,470000
# 4/30/15, 1970 86TH   STREET  ,11214,1725,2112,1931,1,790000
# 7/24/15, 1638 BENSON AVENUE  ,11214,3625,1825,1925,820,000
# 6/25/15, 1653 BATH AVENUE,11214,1260,1440,1930,0
# 6/25/15, 1651 BATH AVENUE,11214,1260,1440,1930,0
# 10/17/15, 1731 BATH AVENUE,11214,1112,1520,1920,0
# 5/12/15, 121 BAY 17TH   STREET,11214,1619,912,1910,0
# 11/2/15, 244 BAY 8TH STREET  ,11228,5720,5152,1930,0
# 12/18/15, 239 BAY8TH STREET   ,11228,5810,1575,1950,1,850000
# 12/7/15, 8804 17TH AVENUE,,3,394,2288,1920,1,192000
# 8/24/15, 1942 BATH AVENUE,11214,2013,1980,1910,895000
# 9/14/15, 2018 BATH AVENUE,11214,1198,1596,1925,745000
# 4/30/15, 173 BAY 26TH STREET ,11214,1837,2337,1901,0
# 1/8/15, 265 BAY 8TH STREET  ,11228,3872,2688,2001,1,450000
# 10/8/15, 310 BAY 10TH STREET ,11228,3867,1399,1935,855000
# 1/16/15, 8846 16TH AVE   ,11214,1937,1240,1950,720000
# 11/2/15, 8870 16TH AVENUE,11214,1760,992,1950,620000
# 10/21/15, 1592 INDEPENDENCE AVENUE,11228,1844,992,1950,750000
# 2/25/15, 319 BAY 14TH STREET ,11214,1511,928,1950,0
# 11-20-15, 277 BAY 14 STREET   ,11214,1795,1204,1930,762000
# 6/5/15, 284 BAY 14TH   STREET,11214,1795,1152,1930,0
# Apr 24 2015, 308 BAY 14TH STREET ,11214,1511,992,1950,650000
# 7/20/15, 279 BAY 13TH   STREET,11214,1649,928,1940,0
# 11/18/15, 1127 SHORE PARKWAY  ,11214,1775,1188,1940,0
# 8/11/15, 8836 BAY 16TH STREET,11214,1865,2982,1960,860000
# 12/29/15, 8894 18TH AVENUE,11214,1361,992,1950,0
# 6/23/15, 287 BAY 20TH    ,11214,1551,1320,1940,675000
# 3/4/15, 241 BAY 23RD STREET ,11214,1783,1120,1945,10000
# 5/26/15, 8661 14TH AVENUE,11228,2,320,2160,1930,980000
# 10/22/15, 70 BAY 7TH STREET   ,11228,2320,2160,1930,750000
# 11/5/15, 37 BAY 7 STREET ,11228,2320,2160,1930,970000
# 4/21/15, 35 BAY 7TH ST   , ,2,320,2160,1930,855000
# 4/21/15, 35 BAY 7TH   STREET ,11228,2320,2160,1930,855000
# 10/21/15, 1592 INDEPENDENCE AVENUE,11228,1844,992,1950,750000
# 6/17/15, 1454 86TH STREET,11228,1600,3034,1931,0
# 11/17/15, 44 BAY 8TH   STREET ,11228,2320,2160,1930,nan
# 2/26/15, 44 BAY 8TH   STREET ,11228,2320,2160,1930,nan
# 12/28/15, 13 BAY 8TH ST   ,11228,2320,3160,1930,10
# 1/13/15, 1513 BENSON AVENUE  ,11228,2142,1920,1945,930000
# 2/17/15, 8625 15TH AVENUE,11228,2,312,2160,1930,950000
# 2/23/15, 37 BAY 10TH   STREET,11228,2103,1622,1930,0
# 10/21/15, 1592 INDEPENDENCE AVENUE,11228,1844,992,1950,750000
# 5/12/15, 31 BAY 10TH STREET  ,11228,2103,1622,1930,840,000
# 3/26/15, 13 BAY 10TH STREET  ,11228,2135,1622,1930,0
# 1/31/15, 8654 16TH AVENUE,11214,2492,2120,1935,0
# 12/28/15, 8653 16TH AVENUE,11214,none,1492,1930,769000

# %% [markdown]
# We may see:
#
# * some rows duplicated,
# * some having too many commas (perhaps due to using them to separate groups of digits in addition to separating fields),
# * missing values,
# * zero values
# * none/nan values
# * inconsistent date formats
#
# This is of course a toy example where all those issues were deliberately "concetrated" within a small sample for illustration purposes, but you can expect similar issues with real-world data as well.

# %%
#pd.read_csv('data/RE_example11.csv') #if we try to read the data it will through an error due to format inconsistency between rows

# %%
re_sales = pd.read_csv('Data/RE_example11.csv', on_bad_lines='skip') #so use on_bad_liness flag to instruct pandas to skip the misformatted lines

# %%
re_sales #the data is read succesfully, while losing some lines; but some issue are still there
# Out:
#       SALE DATE                    ADDRESS  ZIP CODE LAND SQUARE FEET  \
# 0       3/31/15           8647 15TH AVENUE     11228             1547
# 1       3/31/15           8647 15TH AVENUE     11228             1547
# 2       3/31/15           8647 15TH AVENUE     11228             1547
# 3       6/15/15       55 BAY 10TH   STREET     11228             1933
# 4       9/16/15       8620 19TH   AVENUE       11214             2417
# 5      12/17/15       50 BAY 23RD STREET       11214             2417
# 6       6/25/15           1653 BATH AVENUE     11214             1260
# 7       6/25/15           1651 BATH AVENUE     11214             1260
# 8      10/17/15           1731 BATH AVENUE     11214             1112
# 9       5/12/15      121 BAY 17TH   STREET     11214             1619
# 10      11/2/15       244 BAY 8TH STREET       11228             5720
# 11      8/24/15           1942 BATH AVENUE     11214             2013
# 12      9/14/15           2018 BATH AVENUE     11214             1198
# 13      4/30/15       173 BAY 26TH STREET      11214             1837
# 14      10/8/15       310 BAY 10TH STREET      11228             3867
# 15      1/16/15           8846 16TH AVE        11214             1937
# 16      11/2/15           8870 16TH AVENUE     11214             1760
# 17     10/21/15   1592 INDEPENDENCE AVENUE     11228             1844
# 18      2/25/15       319 BAY 14TH STREET      11214             1511
# 19     11-20-15       277 BAY 14 STREET        11214             1795
# 20       6/5/15      284 BAY 14TH   STREET     11214             1795
# 21  Apr 24 2015       308 BAY 14TH STREET      11214             1511
# 22      7/20/15      279 BAY 13TH   STREET     11214             1649
# 23     11/18/15       1127 SHORE PARKWAY       11214             1775
# 24      8/11/15       8836 BAY 16TH STREET     11214             1865
# 25     12/29/15           8894 18TH AVENUE     11214             1361
# 26      6/23/15           287 BAY 20TH         11214             1551
# 27       3/4/15       241 BAY 23RD STREET      11214             1783
# 28     10/22/15       70 BAY 7TH STREET        11228             2320
# 29      11/5/15           37 BAY 7 STREET      11228             2320
# 30      4/21/15       35 BAY 7TH   STREET      11228             2320
# 31     10/21/15   1592 INDEPENDENCE AVENUE     11228             1844
# 32      6/17/15           1454 86TH STREET     11228             1600
# 33     11/17/15       44 BAY 8TH   STREET      11228             2320
# 34      2/26/15       44 BAY 8TH   STREET      11228             2320
# 35     12/28/15           13 BAY 8TH ST        11228             2320
# 36      1/13/15       1513 BENSON AVENUE       11228             2142
# 37      2/23/15       37 BAY 10TH   STREET     11228             2103
# 38     10/21/15   1592 INDEPENDENCE AVENUE     11228             1844
# 39      3/26/15       13 BAY 10TH STREET       11228             2135
# 40      1/31/15           8654 16TH AVENUE     11214             2492
# 41     12/28/15           8653 16TH AVENUE     11214             none
#
#     GROSS SQUARE FEET  YEAR BUILT  SALE PRICE
# 0                1428        1930    758000.0
# 1                1428        1930    758000.0
# 2                1428        1930    758000.0
# 3                1660           0    778000.0
# 4                2106        1930         0.0
# 5                1672        1930    750000.0
# 6                1440        1930         0.0
# 7                1440        1930         0.0
# 8                1520        1920         0.0
# 9                 912        1910         0.0
# 10               5152        1930         0.0
# 11               1980        1910    895000.0
# 12               1596        1925    745000.0
# 13               2337        1901         0.0
# 14               1399        1935    855000.0
# 15               1240        1950    720000.0
# 16                992        1950    620000.0
# 17                992        1950    750000.0
# 18                928        1950         0.0
# 19               1204        1930    762000.0
# 20               1152        1930         0.0
# 21                992        1950    650000.0
# 22                928        1940         0.0
# 23               1188        1940         0.0
# 24               2982        1960    860000.0
# 25                992        1950         0.0
# 26               1320        1940    675000.0
# 27               1120        1945     10000.0
# 28               2160        1930    750000.0
# 29               2160        1930    970000.0
# 30               2160        1930    855000.0
# 31                992        1950    750000.0
# 32               3034        1931         0.0
# 33               2160        1930         NaN
# 34               2160        1930         NaN
# 35               3160        1930        10.0
# 36               1920        1945    930000.0
# 37               1622        1930         0.0
# 38                992        1950    750000.0
# 39               1622        1930         0.0
# 40               2120        1935         0.0
# 41               1492        1930    769000.0

# %%
re_sales.describe() #use basic descriptive analysis to spot them
# Out:
#            ZIP CODE  GROSS SQUARE FEET   YEAR BUILT     SALE PRICE
# count     42.000000          42.000000    42.000000      40.000000
# mean   11220.333333        1697.190476  1888.261905  427950.250000
# std        7.052648         800.496835   298.712690  396534.647534
# min    11214.000000         912.000000     0.000000       0.000000
# 25%    11214.000000        1161.000000  1930.000000       0.000000
# 50%    11214.000000        1466.000000  1930.000000  662500.000000
# 75%    11228.000000        2116.500000  1943.750000  758000.000000
# max    11228.000000        5152.000000  1960.000000  970000.000000

# %%
#we see LAND SQUARE FEET is not included,
#meaining that it is perhaps treated as a string field, rather than date

# %%
re_sales['LAND SQUARE FEET'] = pd.to_numeric(re_sales['LAND SQUARE FEET'], errors='coerce') #convert to numeric, turning invalid parsing to NaN

# %%
(re_sales['SALE DATE'].min(), re_sales['SALE DATE'].max()) #also if we try getting a range for SALE DATE it does not work properly giving us text data
# Out:
# ('1/13/15', 'Apr 24 2015')

# %%
re_sales['SALE DATE'] = pd.to_datetime(re_sales['SALE DATE']) #convert to data-time; it unifies variety of formats

# %%
#now descriptive analysis works as intended
(re_sales['SALE DATE'].min(), re_sales['SALE DATE'].max())
# Out:
# (Timestamp('2015-01-13 00:00:00'), Timestamp('2015-12-29 00:00:00'))

# %%
re_sales.describe() #however min values are 0 for the fiels that should not have zeros
# Out:
#            ZIP CODE  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  \
# count     42.000000         41.000000          42.000000    42.000000
# mean   11220.333333       1988.073171        1697.190476  1888.261905
# std        7.052648        768.055837         800.496835   298.712690
# min    11214.000000       1112.000000         912.000000     0.000000
# 25%    11214.000000       1551.000000        1161.000000  1930.000000
# 50%    11214.000000       1844.000000        1466.000000  1930.000000
# 75%    11228.000000       2320.000000        2116.500000  1943.750000
# max    11228.000000       5720.000000        5152.000000  1960.000000
#
#           SALE PRICE
# count      40.000000
# mean   427950.250000
# std    396534.647534
# min         0.000000
# 25%         0.000000
# 50%    662500.000000
# 75%    758000.000000
# max    970000.000000

# %%
#introduce basic sanity filtering, excluduing zero values
sanityindex = (re_sales['SALE PRICE'] > 0) & (re_sales['YEAR BUILT'] > 0)
re_sales = re_sales.loc[sanityindex]

# %%
re_sales = re_sales.loc[sanityindex]
re_sales.describe() #still min value for the sale price remains unrealistic
# Out:
#            ZIP CODE  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  \
# count     23.000000         22.000000          23.000000    23.000000
# mean   11221.304348       1967.818182        1600.391304  1937.391304
# std        7.150555        534.887406         607.553719    11.761799
# min    11214.000000       1198.000000         992.000000  1910.000000
# 25%    11214.000000       1603.250000        1162.000000  1930.000000
# 50%    11228.000000       1844.000000        1428.000000  1930.000000
# 75%    11228.000000       2275.500000        1950.000000  1950.000000
# max    11228.000000       3867.000000        3160.000000  1960.000000
#
#           SALE PRICE
# count      23.000000
# mean   710435.217391
# std    237812.325123
# min        10.000000
# 25%    732500.000000
# 50%    750000.000000
# 75%    812000.000000
# max    970000.000000

# %%
sanityindex = (re_sales['SALE PRICE'] > 5000) #remove properties worth less than 5000 (in the following case we'll see how one can get some insights on this kind of filtering)
re_sales = re_sales.loc[sanityindex]

# %%
re_sales
# Out:
#     SALE DATE                    ADDRESS  ZIP CODE  LAND SQUARE FEET  \
# 0  2015-03-31           8647 15TH AVENUE     11228            1547.0
# 1  2015-03-31           8647 15TH AVENUE     11228            1547.0
# 2  2015-03-31           8647 15TH AVENUE     11228            1547.0
# 5  2015-12-17       50 BAY 23RD STREET       11214            2417.0
# 11 2015-08-24           1942 BATH AVENUE     11214            2013.0
# 12 2015-09-14           2018 BATH AVENUE     11214            1198.0
# 14 2015-10-08       310 BAY 10TH STREET      11228            3867.0
# 15 2015-01-16           8846 16TH AVE        11214            1937.0
# 16 2015-11-02           8870 16TH AVENUE     11214            1760.0
# 17 2015-10-21   1592 INDEPENDENCE AVENUE     11228            1844.0
# 19 2015-11-20       277 BAY 14 STREET        11214            1795.0
# 21 2015-04-24       308 BAY 14TH STREET      11214            1511.0
# 24 2015-08-11       8836 BAY 16TH STREET     11214            1865.0
# 26 2015-06-23           287 BAY 20TH         11214            1551.0
# 27 2015-03-04       241 BAY 23RD STREET      11214            1783.0
# 28 2015-10-22       70 BAY 7TH STREET        11228            2320.0
# 29 2015-11-05           37 BAY 7 STREET      11228            2320.0
# 30 2015-04-21       35 BAY 7TH   STREET      11228            2320.0
# 31 2015-10-21   1592 INDEPENDENCE AVENUE     11228            1844.0
# 36 2015-01-13       1513 BENSON AVENUE       11228            2142.0
# 38 2015-10-21   1592 INDEPENDENCE AVENUE     11228            1844.0
# 41 2015-12-28           8653 16TH AVENUE     11214               NaN
#
#     GROSS SQUARE FEET  YEAR BUILT  SALE PRICE
# 0                1428        1930    758000.0
# 1                1428        1930    758000.0
# 2                1428        1930    758000.0
# 5                1672        1930    750000.0
# 11               1980        1910    895000.0
# 12               1596        1925    745000.0
# 14               1399        1935    855000.0
# 15               1240        1950    720000.0
# 16                992        1950    620000.0
# 17                992        1950    750000.0
# 19               1204        1930    762000.0
# 21                992        1950    650000.0
# 24               2982        1960    860000.0
# 26               1320        1940    675000.0
# 27               1120        1945     10000.0
# 28               2160        1930    750000.0
# 29               2160        1930    970000.0
# 30               2160        1930    855000.0
# 31                992        1950    750000.0
# 36               1920        1945    930000.0
# 38                992        1950    750000.0
# 41               1492        1930    769000.0

# %%
#two remaining issues are nan values and duplicate rows address those below

# %%
re_sales = re_sales.loc[sanityindex].dropna()

# %%
re_sales = pd.DataFrame.drop_duplicates(re_sales)
#new pandas versions have .drop_duplicates as a method of a dataframe enabling re_sales.drop_duplicated(inplace = True)

# %%
re_sales #finally we can see that the index now have gaps as we dropped quite a few records
# Out:
#     SALE DATE                    ADDRESS  ZIP CODE  LAND SQUARE FEET  \
# 0  2015-03-31           8647 15TH AVENUE     11228            1547.0
# 5  2015-12-17       50 BAY 23RD STREET       11214            2417.0
# 11 2015-08-24           1942 BATH AVENUE     11214            2013.0
# 12 2015-09-14           2018 BATH AVENUE     11214            1198.0
# 14 2015-10-08       310 BAY 10TH STREET      11228            3867.0
# 15 2015-01-16           8846 16TH AVE        11214            1937.0
# 16 2015-11-02           8870 16TH AVENUE     11214            1760.0
# 17 2015-10-21   1592 INDEPENDENCE AVENUE     11228            1844.0
# 19 2015-11-20       277 BAY 14 STREET        11214            1795.0
# 21 2015-04-24       308 BAY 14TH STREET      11214            1511.0
# 24 2015-08-11       8836 BAY 16TH STREET     11214            1865.0
# 26 2015-06-23           287 BAY 20TH         11214            1551.0
# 27 2015-03-04       241 BAY 23RD STREET      11214            1783.0
# 28 2015-10-22       70 BAY 7TH STREET        11228            2320.0
# 29 2015-11-05           37 BAY 7 STREET      11228            2320.0
# 30 2015-04-21       35 BAY 7TH   STREET      11228            2320.0
# 36 2015-01-13       1513 BENSON AVENUE       11228            2142.0
#
#     GROSS SQUARE FEET  YEAR BUILT  SALE PRICE
# 0                1428        1930    758000.0
# 5                1672        1930    750000.0
# 11               1980        1910    895000.0
# 12               1596        1925    745000.0
# 14               1399        1935    855000.0
# 15               1240        1950    720000.0
# 16                992        1950    620000.0
# 17                992        1950    750000.0
# 19               1204        1930    762000.0
# 21                992        1950    650000.0
# 24               2982        1960    860000.0
# 26               1320        1940    675000.0
# 27               1120        1945     10000.0
# 28               2160        1930    750000.0
# 29               2160        1930    970000.0
# 30               2160        1930    855000.0
# 36               1920        1945    930000.0

# %%
re_sales.reset_index(inplace = True, drop = True) #if we want it consistent we can reset index
re_sales
# Out:
#     SALE DATE                    ADDRESS  ZIP CODE  LAND SQUARE FEET  \
# 0  2015-03-31           8647 15TH AVENUE     11228            1547.0
# 1  2015-12-17       50 BAY 23RD STREET       11214            2417.0
# 2  2015-08-24           1942 BATH AVENUE     11214            2013.0
# 3  2015-09-14           2018 BATH AVENUE     11214            1198.0
# 4  2015-10-08       310 BAY 10TH STREET      11228            3867.0
# 5  2015-01-16           8846 16TH AVE        11214            1937.0
# 6  2015-11-02           8870 16TH AVENUE     11214            1760.0
# 7  2015-10-21   1592 INDEPENDENCE AVENUE     11228            1844.0
# 8  2015-11-20       277 BAY 14 STREET        11214            1795.0
# 9  2015-04-24       308 BAY 14TH STREET      11214            1511.0
# 10 2015-08-11       8836 BAY 16TH STREET     11214            1865.0
# 11 2015-06-23           287 BAY 20TH         11214            1551.0
# 12 2015-03-04       241 BAY 23RD STREET      11214            1783.0
# 13 2015-10-22       70 BAY 7TH STREET        11228            2320.0
# 14 2015-11-05           37 BAY 7 STREET      11228            2320.0
# 15 2015-04-21       35 BAY 7TH   STREET      11228            2320.0
# 16 2015-01-13       1513 BENSON AVENUE       11228            2142.0
#
#     GROSS SQUARE FEET  YEAR BUILT  SALE PRICE
# 0                1428        1930    758000.0
# 1                1672        1930    750000.0
# 2                1980        1910    895000.0
# 3                1596        1925    745000.0
# 4                1399        1935    855000.0
# 5                1240        1950    720000.0
# 6                 992        1950    620000.0
# 7                 992        1950    750000.0
# 8                1204        1930    762000.0
# 9                 992        1950    650000.0
# 10               2982        1960    860000.0
# 11               1320        1940    675000.0
# 12               1120        1945     10000.0
# 13               2160        1930    750000.0
# 14               2160        1930    970000.0
# 15               2160        1930    855000.0
# 16               1920        1945    930000.0

# %% [markdown]
# We can see that only 16 out of 41 records survived the data cleaning. It is not always that bad, but as we'll see from the following real world case if can sometimes be even worse...

# %% [markdown]
# ## Homework - part 1

# %%
# please note that this is just a toy dataset, you don't need to follow the exactly the same data cleaning steps
# when working on a real citibike dataset
url = 'https://raw.githubusercontent.com/CUSP2020PUI/Data/master/citibike.csv'
citibike = pd.read_csv(url)

# %%
citibike.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2020-08-01 00:00:00.8790  2020-08-01 00:33:34.7260              3295
# 1  2020-08-01 00:00:01.5910  2020-08-01 01:56:44.0720              3144
# 2  2020-08-01 00:00:03.5810  2020-08-01 00:02:38.6340               387
# 3  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270              3080
# 4  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270              3080
#
#          start station name  start station latitude  start station longitude  \
# 0  Central Park W & W 96 St               40.791270               -73.964839
# 1        E 81 St & Park Ave               40.776777               -73.959010
# 2   Centre St & Chambers St               40.712733               -74.004607
# 3        S 4 St & Rodney St               40.709340               -73.956080
# 4        S 4 St & Rodney St               40.709340               -73.956080
#
#    end station id                end station name  end station latitude  \
# 0            3992  W 169 St & Fort Washington Ave             40.842842
# 1            3671                 E 81 St & 2 Ave             40.774779
# 2             387         Centre St & Chambers St             40.712733
# 3            3364              Carroll St & 5 Ave             40.675162
# 4            3364              Carroll St & 5 Ave             40.675162
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.942125   19706    Customer        1998     1.0
# 1             -73.954275   37191  Subscriber        1966     1.0
# 2             -74.004607   42561    Customer        1969     0.0
# 3             -73.981483   41607  Subscriber        1990     1.0
# 4             -73.981483   41607  Subscriber        1990     1.0

# %%
citibike.shape
# Out:
# (100, 14)

# %% [markdown]
# ### task 1
# Filter out trips with unreasonal trip duration. Trip duration has to be a positive number, and shorter than 3 hours.
#
# Hint:
#     1. convert starttime, endtime to timestamp at first
#     2. use .astype('timedelta64[m]') to get trip duration in minutes

# %%
# Convert starttime, endtime to timestamp
citibike['starttime'] = pd.to_datetime(citibike['starttime'])
citibike['stoptime'] = pd.to_datetime(citibike['stoptime'])
citibike['trip_duration'] = (citibike['stoptime'] - citibike['starttime']).astype('timedelta64[m]')

# %%
citibike.head()
# Out:
#                 starttime                stoptime  start station id  \
# 0 2020-08-01 00:00:00.879 2020-08-01 00:33:34.726              3295
# 1 2020-08-01 00:00:01.591 2020-08-01 01:56:44.072              3144
# 2 2020-08-01 00:00:03.581 2020-08-01 00:02:38.634               387
# 3 2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# 4 2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
#
#          start station name  start station latitude  start station longitude  \
# 0  Central Park W & W 96 St               40.791270               -73.964839
# 1        E 81 St & Park Ave               40.776777               -73.959010
# 2   Centre St & Chambers St               40.712733               -74.004607
# 3        S 4 St & Rodney St               40.709340               -73.956080
# 4        S 4 St & Rodney St               40.709340               -73.956080
#
#    end station id                end station name  end station latitude  \
# 0            3992  W 169 St & Fort Washington Ave             40.842842
# 1            3671                 E 81 St & 2 Ave             40.774779
# 2             387         Centre St & Chambers St             40.712733
# 3            3364              Carroll St & 5 Ave             40.675162
# 4            3364              Carroll St & 5 Ave             40.675162
#
#    end station longitude  bikeid    usertype  birth year  gender  \
# 0             -73.942125   19706    Customer        1998     1.0
# 1             -73.954275   37191  Subscriber        1966     1.0
# 2             -74.004607   42561    Customer        1969     0.0
# 3             -73.981483   41607  Subscriber        1990     1.0
# 4             -73.981483   41607  Subscriber        1990     1.0
#
#    trip_duration
# 0           33.0
# 1          116.0
# 2            2.0
# 3           45.0
# 4           45.0

# %%
# filter the negative values and the values that shorter than 3 hours
sanityindex = (citibike['trip_duration'] > 0) & (citibike['trip_duration'] < 180)
citibike = citibike.loc[sanityindex]

# %%
citibike.drop(columns=['trip_duration'],inplace=True)
citibike
# Out:
#                  starttime                stoptime  start station id  \
# 0  2020-08-01 00:00:00.879 2020-08-01 00:33:34.726              3295
# 1  2020-08-01 00:00:01.591 2020-08-01 01:56:44.072              3144
# 2  2020-08-01 00:00:03.581 2020-08-01 00:02:38.634               387
# 3  2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# 4  2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# ..                     ...                     ...               ...
# 95 2020-08-01 00:02:30.910 2020-08-01 00:22:12.494               346
# 96 2020-08-01 00:02:31.138 2020-08-01 00:12:03.717              3664
# 97 2020-08-01 00:02:32.498 2020-08-01 00:09:59.658              3718
# 98 2020-08-01 00:02:37.353 2020-08-01 00:07:48.049              3328
# 99 2020-08-01 00:02:40.765 2020-08-01 00:32:20.174               418
#
#                start station name  start station latitude  \
# 0        Central Park W & W 96 St               40.791270
# 1              E 81 St & Park Ave               40.776777
# 2         Centre St & Chambers St               40.712733
# 3              S 4 St & Rodney St               40.709340
# 4              S 4 St & Rodney St               40.709340
# ..                            ...                     ...
# 95            Bank St & Hudson St               40.736529
# 96  North Moore St & Greenwich St               40.720195
# 97             E 11 St & Avenue B               40.727464
# 98       W 100 St & Manhattan Ave               40.795000
# 99             Front St & Gold St               40.702240
#
#     start station longitude  end station id                end station name  \
# 0                -73.964839            3992  W 169 St & Fort Washington Ave
# 1                -73.959010            3671                 E 81 St & 2 Ave
# 2                -74.004607             387         Centre St & Chambers St
# 3                -73.956080            3364              Carroll St & 5 Ave
# 4                -73.956080            3364              Carroll St & 5 Ave
# ..                      ...             ...                             ...
# 95               -74.006180             514                12 Ave & W 40 St
# 96               -74.010301             363                  West Thames St
# 97               -73.979504             507                 E 25 St & 2 Ave
# 98               -73.964500            3283          W 89 St & Columbus Ave
# 99               -73.982578            3569     Franklin Ave & St Marks Ave
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.842842             -73.942125   19706    Customer
# 1              40.774779             -73.954275   37191  Subscriber
# 2              40.712733             -74.004607   42561    Customer
# 3              40.675162             -73.981483   41607  Subscriber
# 4              40.675162             -73.981483   41607  Subscriber
# ..                   ...                    ...     ...         ...
# 95             40.760875             -74.002777   32583    Customer
# 96             40.708347             -74.017134   41286  Subscriber
# 97             40.739126             -73.979738   19007  Subscriber
# 98             40.788221             -73.970416   38405  Subscriber
# 99             40.675832             -73.956168   29912    Customer
#
#     birth year  gender
# 0         1998     1.0
# 1         1966     1.0
# 2         1969     0.0
# 3         1990     1.0
# 4         1990     1.0
# ..         ...     ...
# 95        1969     0.0
# 96        1988     2.0
# 97        1993     1.0
# 98        1997     1.0
# 99        1989     1.0
#
# [98 rows x 14 columns]

# %%
citibike.shape
# Out:
# (98, 14)

# %% [markdown]
# ### task 2
# Remove trip records which include unrealistic costumer age.
#
# Hint:
#     1. Customer age has to be less than 100.

# %%
citibike['birth year'] = pd.to_numeric(citibike['birth year'], errors='coerce') #convert to numeric, turning invalid parsing to NaN
citibike['costumer age']=int(2023)-citibike['birth year']
citibike
# Out:
#                  starttime                stoptime  start station id  \
# 0  2020-08-01 00:00:00.879 2020-08-01 00:33:34.726              3295
# 1  2020-08-01 00:00:01.591 2020-08-01 01:56:44.072              3144
# 2  2020-08-01 00:00:03.581 2020-08-01 00:02:38.634               387
# 3  2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# 4  2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# ..                     ...                     ...               ...
# 95 2020-08-01 00:02:30.910 2020-08-01 00:22:12.494               346
# 96 2020-08-01 00:02:31.138 2020-08-01 00:12:03.717              3664
# 97 2020-08-01 00:02:32.498 2020-08-01 00:09:59.658              3718
# 98 2020-08-01 00:02:37.353 2020-08-01 00:07:48.049              3328
# 99 2020-08-01 00:02:40.765 2020-08-01 00:32:20.174               418
#
#                start station name  start station latitude  \
# 0        Central Park W & W 96 St               40.791270
# 1              E 81 St & Park Ave               40.776777
# 2         Centre St & Chambers St               40.712733
# 3              S 4 St & Rodney St               40.709340
# 4              S 4 St & Rodney St               40.709340
# ..                            ...                     ...
# 95            Bank St & Hudson St               40.736529
# 96  North Moore St & Greenwich St               40.720195
# 97             E 11 St & Avenue B               40.727464
# 98       W 100 St & Manhattan Ave               40.795000
# 99             Front St & Gold St               40.702240
#
#     start station longitude  end station id                end station name  \
# 0                -73.964839            3992  W 169 St & Fort Washington Ave
# 1                -73.959010            3671                 E 81 St & 2 Ave
# 2                -74.004607             387         Centre St & Chambers St
# 3                -73.956080            3364              Carroll St & 5 Ave
# 4                -73.956080            3364              Carroll St & 5 Ave
# ..                      ...             ...                             ...
# 95               -74.006180             514                12 Ave & W 40 St
# 96               -74.010301             363                  West Thames St
# 97               -73.979504             507                 E 25 St & 2 Ave
# 98               -73.964500            3283          W 89 St & Columbus Ave
# 99               -73.982578            3569     Franklin Ave & St Marks Ave
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.842842             -73.942125   19706    Customer
# 1              40.774779             -73.954275   37191  Subscriber
# 2              40.712733             -74.004607   42561    Customer
# 3              40.675162             -73.981483   41607  Subscriber
# 4              40.675162             -73.981483   41607  Subscriber
# ..                   ...                    ...     ...         ...
# 95             40.760875             -74.002777   32583    Customer
# 96             40.708347             -74.017134   41286  Subscriber
# 97             40.739126             -73.979738   19007  Subscriber
# 98             40.788221             -73.970416   38405  Subscriber
# 99             40.675832             -73.956168   29912    Customer
#
#     birth year  gender  costumer age
# 0         1998     1.0            25
# 1         1966     1.0            57
# 2         1969     0.0            54
# 3         1990     1.0            33
# 4         1990     1.0            33
# ..         ...     ...           ...
# 95        1969     0.0            54
# 96        1988     2.0            35
# 97        1993     1.0            30
# 98        1997     1.0            26
# 99        1989     1.0            34
#
# [98 rows x 15 columns]

# %%
#introduce basic sanity filtering, excluduing zero values
sanityindex = (citibike['costumer age'] > 0) & (citibike['costumer age'] < 100)
citibike = citibike.loc[sanityindex]

# %%
citibike.drop(columns=['costumer age'],inplace=True)
# Out:
# <ipython-input-129-36ab317ec7f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citibike.drop(columns=['costumer age'],inplace=True)

# %%
citibike
# Out:
#                  starttime                stoptime  start station id  \
# 0  2020-08-01 00:00:00.879 2020-08-01 00:33:34.726              3295
# 1  2020-08-01 00:00:01.591 2020-08-01 01:56:44.072              3144
# 2  2020-08-01 00:00:03.581 2020-08-01 00:02:38.634               387
# 3  2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# 4  2020-08-01 00:00:05.013 2020-08-01 00:45:25.327              3080
# ..                     ...                     ...               ...
# 95 2020-08-01 00:02:30.910 2020-08-01 00:22:12.494               346
# 96 2020-08-01 00:02:31.138 2020-08-01 00:12:03.717              3664
# 97 2020-08-01 00:02:32.498 2020-08-01 00:09:59.658              3718
# 98 2020-08-01 00:02:37.353 2020-08-01 00:07:48.049              3328
# 99 2020-08-01 00:02:40.765 2020-08-01 00:32:20.174               418
#
#                start station name  start station latitude  \
# 0        Central Park W & W 96 St               40.791270
# 1              E 81 St & Park Ave               40.776777
# 2         Centre St & Chambers St               40.712733
# 3              S 4 St & Rodney St               40.709340
# 4              S 4 St & Rodney St               40.709340
# ..                            ...                     ...
# 95            Bank St & Hudson St               40.736529
# 96  North Moore St & Greenwich St               40.720195
# 97             E 11 St & Avenue B               40.727464
# 98       W 100 St & Manhattan Ave               40.795000
# 99             Front St & Gold St               40.702240
#
#     start station longitude  end station id                end station name  \
# 0                -73.964839            3992  W 169 St & Fort Washington Ave
# 1                -73.959010            3671                 E 81 St & 2 Ave
# 2                -74.004607             387         Centre St & Chambers St
# 3                -73.956080            3364              Carroll St & 5 Ave
# 4                -73.956080            3364              Carroll St & 5 Ave
# ..                      ...             ...                             ...
# 95               -74.006180             514                12 Ave & W 40 St
# 96               -74.010301             363                  West Thames St
# 97               -73.979504             507                 E 25 St & 2 Ave
# 98               -73.964500            3283          W 89 St & Columbus Ave
# 99               -73.982578            3569     Franklin Ave & St Marks Ave
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.842842             -73.942125   19706    Customer
# 1              40.774779             -73.954275   37191  Subscriber
# 2              40.712733             -74.004607   42561    Customer
# 3              40.675162             -73.981483   41607  Subscriber
# 4              40.675162             -73.981483   41607  Subscriber
# ..                   ...                    ...     ...         ...
# 95             40.760875             -74.002777   32583    Customer
# 96             40.708347             -74.017134   41286  Subscriber
# 97             40.739126             -73.979738   19007  Subscriber
# 98             40.788221             -73.970416   38405  Subscriber
# 99             40.675832             -73.956168   29912    Customer
#
#     birth year  gender
# 0         1998     1.0
# 1         1966     1.0
# 2         1969     0.0
# 3         1990     1.0
# 4         1990     1.0
# ..         ...     ...
# 95        1969     0.0
# 96        1988     2.0
# 97        1993     1.0
# 98        1997     1.0
# 99        1989     1.0
#
# [95 rows x 14 columns]

# %%
citibike.shape
# Out:
# (95, 14)

# %% [markdown]
# ### task 3
# drop duplicated records

# %%
citibike = pd.DataFrame.drop_duplicates(citibike)
#new pandas versions have .drop_duplicates as a method of a dataframe enabling re_sales.drop_duplicated(inplace = True)

# %%
citibike.shape
# Out:
# (93, 14)

# %% [markdown]
# ### task 4
# Find records where start location or end location is outside of New York City, then delete them.
#
# NYC latitude, longitude range is available at https://www1.nyc.gov/assets/planning/download/pdf/data-maps/open-data/nybb_metadata.pdf?ver=18c as
#
#     West -74.257159 East -73.699215
#     North 40.915568 South 40.495992

# %%
#introduce basic sanity filtering, excluduing zero values
sanityindex_location_start = ( citibike['start station latitude'] > 40.495992 ) & ( citibike['start station latitude'] < 40.915568 )  & ( citibike['start station longitude'] < -73.699215 )& ( citibike['start station longitude'] > -74.257159 )
citibike = citibike.loc[sanityindex_location_start]

# %%
#introduce basic sanity filtering, excluduing zero values
sanityindex_location_end = ( citibike['end station latitude'] > 40.495992 ) & ( citibike['end station latitude'] < 40.915568 )  & ( citibike['end station longitude'] < -73.699215 )& ( citibike['end station longitude'] > -74.257159 )
citibike = citibike.loc[sanityindex_location_end]

# %%
citibike.shape
# Out:
# (91, 14)
